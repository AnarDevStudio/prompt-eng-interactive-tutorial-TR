# %% [markdown]
# # Eğitim Nasıl Yapılır
#
# Bu eğitim, atölye çalışmasındaki tüm not defterleri için gereksinimlerin ve ortam değişkenlerinin saklanması amacıyla önce bu başlangıç not defterinin çalıştırılmasını gerektirir

# %% [markdown]
# ## Nasıl Başlanır
#
# 1. Bu depoyu yerel makinenize klonlayın.
#
# 2. Aşağıdaki komutu çalıştırarak gerekli bağımlılıkları yükleyin:

# %%
# %pip install -qU pip
# %pip install -qr ../requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 3. Restart the kernel after installing dependencies

# %%
# karneli sifirla
from IPython.core.display import HTML
HTML("<script>Jupyter.notebook.kernel.restart()</script>")

# %% [markdown]
# ---
# ## Kullanım Notları & İpuçları 💡
#
# - Bu kurs, sıcaklık değeri 0 olan Claude 3 Haiku kullanır. Sıcaklık hakkında kursta daha fazla konuşacağız. Şimdilik, bu ayarların daha deterministik sonuçlar verdiğini anlamak yeterli. Bu kurstaki tüm prompt mühendislik teknikleri, Claude 2 ve Claude Instant 1.2 gibi önceki nesil eski Claude modellerine de uygulanır.
# - Hücreyi çalıştırmak ve bir sonrakine geçmek için `Shift + Enter` kullanabilirsiniz.
# - Bir eğitim sayfasının altına ulaştığınızda, klasördeki bir sonraki numaralı dosyaya veya o bölüm dosyasındaki içeriği bitirdiyseniz bir sonraki numaralı klasöre gidin.
#
# ### Anthropic SDK & Messages API
#
# Bu eğitim boyunca [Anthropic python SDK](https://docs.anthropic.com/claude/reference/claude-on-amazon-bedrock) ve [Messages API](https://docs.anthropic.com/claude/reference/messages_post) kullanacağız.
# Aşağıda, bu eğitimde bir prompt çalıştırmanın nasıl görüneceğine dair bir örnek bulunmaktadır.
#
# ---

# %% [markdown]
# Önce model adını ve bölgeyi ayarlayıp saklıyoruz.

# %%
import boto3
session = boto3.Session() # bölge adını dinamik olarak almak ve ayarlamak için bir boto3 oturumu oluştur
AWS_REGION = session.region_name
print("AWS Region:", AWS_REGION)
MODEL_NAME = "anthropic.claude-3-haiku-20240307-v1:0"

# %store MODEL_NAME
# %store AWS_REGION

# %% [markdown]
# Ardından, Claude'a bir prompt gönderen ve Claude'un ürettiği yanıtı döndüren bir yardımcı fonksiyon olan `get_completion`'ı oluşturuyoruz. Bu hücreyi şimdi çalıştırın.

# %%
from anthropic import AnthropicBedrock

client = AnthropicBedrock(aws_region=AWS_REGION)

def get_completion(prompt, system=''):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=2000,
        temperature=0.0,
        messages=[
          {"role": "user", "content": prompt}
        ],
        system=system
    )
    return message.content[0].text

# %% [markdown]
# Şimdi Claude için örnek bir prompt yazacağız ve `get_completion` yardımcı fonksiyonumuzu çalıştırarak Claude'un çıktısını yazdıracağız. Aşağıdaki hücreyi çalıştırmak, altında Claude'dan bir yanıt yazdıracaktır.
# Claude'dan farklı yanıtlar almak için prompt dizesiyle oynamaktan çekinmeyin.

# %%
# Prompt
prompt = "Selma, Claude!"

# Claude Cevabini Aliyoruz
print(get_completion(prompt))

# %% [markdown]
# Daha önce tanımlanan `MODEL_NAME` ve `AWS_REGION` değişkenleri eğitim boyunca kullanılacaktır. Sadece her eğitim sayfası için hücreleri yukarıdan aşağıya doğru çalıştırdığınızdan emin olun.
